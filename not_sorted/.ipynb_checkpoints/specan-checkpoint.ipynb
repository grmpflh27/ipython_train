# %%
# %matplotlib inline

# %% [markdown]
# ## RCMC (aegean_sea beam 0)

# %%
f = np.load('/Users/tbeyer/SAR/PALSAR_DATA/SCANSAR_aegean_sea/ALPSRS106382800-L1.0/pixel_shift.npy')

# %%
plt.plot(np.abs(f), np.arange(np.size(f)))

# %% [markdown]
# ## TEST

# %%
first_offsets = [327, 574, 930, 1204, 0]
start_data_idxs = [189, 214, 249, 277, 196]

# %%
plt.plot(np.arange(np.size(first_offsets)), first_offsets, 'x', np.arange(np.size(first_offsets)), start_data_idxs, 'x', lw=5)

# %%
# %lsmagic

# %% [markdown]
# # Antenna pattern (aegean_sea beam 0)

# %%
file0 = '/Users/tbeyer/SAR/PALSAR_DATA/SCANSAR_aegean_sea/ALPSRS106382800-L1.0/antenna_pat_0.npy'

rg_beam_pattern = np.load(file0)

print np.min(rg_beam_pattern), np.max(rg_beam_pattern)

plt.figure(figsize=(20,10))

plt.plot(10 * np.log10(rg_beam_pattern))
# Out:
# 1.69741620683e-12 1.0

# %%
file1 = '/Users/tbeyer/SAR/PALSAR_DATA/SCANSAR_aegean_sea/ALPSRS106382800-L1.0/antenna_pat_0_pi.npy'

rg_beam_pattern_pi = np.load(file1)

plt.figure(figsize=(10,10))

plt.plot(1- (10 * np.log10(rg_beam_pattern_pi)))
